# %% [markdown]
# Create A Bank Model
#
#
#
# A Bank should
#
# Allow creation of different bank accounts
#
# It should allow us to perform transactions like
#
# deposit
#
# withdraw
#
# transfer between accounts
#
# credit interest to all accounts
#
#
#
# There are different types of BankAccount
#
#
#
#
#
#
#
#
#
# Account Type
#
# Deposit
#
# Widthraw
#
# Credit Interest
#
# Savings
#
#
#
# Min Balance required is 5000
#
# if you have 20000 youc an withraw upto 15000 only
#
#
#
# standard rate
#
# Current
#
#
#
# Can withdraw upto the balance
#
# no interest
#
# OverdraftAccount
#
#
#
# Can withdraw upto balance+odLimit
#
#
#
# odLimit is 10% of historic max balance
#
# odFee is 1% of od
#
# Example
#
# if your alltime max balance is 1Lac
#
# odLimit is 10K
#
# if you current balance is 20K
#
# you can withdraw upto 20+10=30 K
#
# if you withdraw 25K
#
# od = 25-20=5000
#
# od fee= 1% of 5000=50
#
# Your final balance
#
# 20000-25000-50=-5050
#
# standar rate
#
# Important
#
#
#
# class Bank is not replacing class BankAccount
#
# we need both objects
#
# Bank
#
# BankAccount
#
#
#
# when we deposit money to bank, it calls the deposit of bankaccount object
#
#
#
# Example
#
#
#
# icici = Bank()
#
#
#
# a1 = icici.open_account('Vivek', 'p@ss', 50000, SavingsAccount) # 1
#
# a2 = icici.open_accont('Sanjay', 'p@ss', 50000, OverdraftAccount) #2
#
#
#
#
#
# icici.transfer( a1, 10000, 'p@ss', a2) # internally calls withdraw for a1 and deposit for a2
#
#
#
#
#
#
#
# *** 3 ATM object ***
#
#
#
#
#
# there should be an ATM object that will allow user to interact with the bank and bank account
#
# It should be the only class to have print and input

# %%
from bank import Bank

class BankAccount():

    def __init__(self):
        pass

    def create_acc(self,accType,name,balance,pin,interestrate):
        self._pin = pin
        self._accNo = 999
        self._accType = accType
        self._name = name
        self._interest = interestrate
        if self._accType == "SA":
            if balance>=5000:
                self._balance = balance
            else:
                print("less balance to start the account")
                self._accType = None
                self._name = None
        elif self._accType == "ODA":
            self._eStatement = list()
            self._eStatement.append(balance)
            self._balance = balance
        else:
            self._balance = balance

    def withdraw(self,amt):
        if self._accType == "SA":
            if self._balance-amt>=5000:
                self._balance = self._balance-amt
            else:
                print(f'Not able to withdraw {amt}')
        elif self._accType == "ODA":
            maximum_bal = max(self._eStatement)
            limit = self._balance+maximum_bal*0.1
            if  limit-amt>=0:
                    print("Limit:",limit)
                    print("state",self._eStatement)
                    odFee = 0
                    if self._balance-amt<0:
                        odFee = (self._balance-amt)*0.01
                        print(f'odFee:{odFee}')
                    self._balance = self._balance - amt + odFee
            else:
                print("The witdraw amount is off Limit")
        else:
            if self._balance - amt>=0:
                self._balance = self._balance - amt
            else:
                print(f'Low Balance')



    def deposit(self,amt):
        self._balance = self._balance + amt
        if self._accType=="ODA":
            self._eStatement.append(self._balance)
         
    def transfer(self,senderACC,amt,pin):
        if self._accType == "SA" and self._pin == pin:
            if self._balance-amt>=5000:
                 senderACC._balance += amt
                 self._balance = self._balance-amt
            else:
                print(f'Low balance')
        elif self._accType == "ODA"and self._pin == pin:
            maximum_bal = max(self._eStatement)
            limit = self._balance+maximum_bal*0.1
            if  limit-amt>=0:
                    print("Limit:",limit)
                    print("state",self._eStatement)
                    odFee = 0
                    if self._balance-amt<0:
                        odFee = (self._balance-amt)*0.01
                        print(f'odFee:{odFee}')
                    self._balance = self._balance - amt + odFee
                    senderACC._balance = amt
            else:
                print("The witdraw amount is off Limit")
        elif self._pin == pin:
            if self._balance - amt>=0:
                self._balance = self._balance - amt
                senderACC._balance += amt

            else:
                print(f'Low Balance')
        else:
            print("Invalid Pin")


    def creditInterest(self):
        if self._accType == "SA":
            self._balance = self._balance + self._balance*self._interest/100
        elif self._accType == "ODA":
            if self._balance > 0:
                self._balance = self._balance + self._balance*self._interest/100
        else:
            print("No Interest on Current Account")

# %% [markdown]
# *** ATM ***

# %%
class atm(Bank,BankAccount):
    def __init__(self, bname, address, ifsc):
        Bank.__init__(self,bname, address, ifsc)
        BankAccount.__init__(self)

    def create(self,accType,name,balance,pin,interestrate):
        super().create_acc(accType,name,balance,pin,interestrate)

    def withdraw(self, amt):
        return super().withdraw(amt)
    
    def deposit(self, amt):
        return super().deposit(amt)
    
    def creditInterest(self):
        return super().creditInterest()

    def info(self):
        print("*"*100)
        print(f'ACCNUM:{self._accNo}\tNAME:{self._name}\nAccType:{self._accType}\tBALANCE:{self._balance}')
        print("_"*100)

# %%
b = atm("BOB","TUM","BOBTUM")
b.create("SA","harsha",56000,1018,8)
b.info()
b.deposit(5000)
# b.withdraw(56000)
# print(b._balance)

c = atm("BOB","TUM","BOBTUM")
c.create("SA","Sow",5000,1018,8)
c.info()
c.deposit(5000)
c.withdraw(56000)
b.transfer(c,5000,1018)
c.info()
# Out:
# ****************************************************************************************************
# ACCNUM:999	NAME:harsha
# AccType:SA	BALANCE:56000
# ____________________________________________________________________________________________________
# ****************************************************************************************************
# ACCNUM:999	NAME:Sow
# AccType:SA	BALANCE:5000
# ____________________________________________________________________________________________________
# Not able to withdraw 56000
# ****************************************************************************************************
# ACCNUM:999	NAME:Sow
# AccType:SA	BALANCE:15000
# ____________________________________________________________________________________________________
